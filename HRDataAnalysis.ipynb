# %% [markdown]
# ## **Afame Technologies Data Analysis Internship Task 2**

# %% [markdown]
# ## **HR Data Analysis**

# %% [markdown]
# **Activities to complete:**
# 1. Data cleansing involves removing unnecessary columns.
#
# 2. Giving the columns new names.
#
# 3. Eliminating redundant entries.
#
# 4. sanitizing specific columns.
#
# 5. Eliminate the dataset's NaN values.
#
# Look for a few more changes if necessary

# %%
# Import all the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Import dataset
df = pd.read_csv("HR Data.csv")

# %%
# Read dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Shape of data
df.shape
# Out:
# (1470, 35)

# %%
# Unique Columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Statistical Description of data
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Checking for Null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# Check for Duplicated records
df.duplicated().sum()
# Out:
# 0

# %%
data=df[['Age','OverTime','MaritalStatus','JobRole','Gender','EducationField','Department',
           'BusinessTravel','Education','DistanceFromHome','DailyRate','Attrition']]

# %%
data.rename({'BusinessTravel':'Business Travel','EducationField':'Education Field',
               'MaritalStatus':'Marital Status','OverTime':'Over Time'})

data.head()
# Out:
#    Age OverTime MaritalStatus                JobRole  Gender EducationField  \
# 0   41      Yes        Single        Sales Executive  Female  Life Sciences
# 1   49       No       Married     Research Scientist    Male  Life Sciences
# 2   37      Yes        Single  Laboratory Technician    Male          Other
# 3   33      Yes       Married     Research Scientist  Female  Life Sciences
# 4   27       No       Married  Laboratory Technician    Male        Medical
#
#                Department     BusinessTravel  Education  DistanceFromHome  \
# 0                   Sales      Travel_Rarely          2                 1
# 1  Research & Development  Travel_Frequently          1                 8
# 2  Research & Development      Travel_Rarely          2                 2
# 3  Research & Development  Travel_Frequently          4                 3
# 4  Research & Development      Travel_Rarely          1                 2
#
#    DailyRate Attrition
# 0       1102       Yes
# ...

# %%
data['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
data['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
data['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
data['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
sales_markt=data[(data['Department']=='Sales') & (data['EducationField']=='Marketing') ]
sales_markt.head()
# Out:
#     Age OverTime MaritalStatus               JobRole  Gender EducationField  \
# 27   42       No       Married       Sales Executive    Male      Marketing
# 29   46       No        Single               Manager  Female      Marketing
# 36   50      Yes       Married  Sales Representative    Male      Marketing
# 37   35       No       Married  Sales Representative  Female      Marketing
# 46   34       No        Single       Sales Executive    Male      Marketing
#
#    Department BusinessTravel  Education  DistanceFromHome  DailyRate Attrition
# 27      Sales  Travel_Rarely          4                 8        691        No
# 29      Sales  Travel_Rarely          4                 2        705        No
# 36      Sales  Travel_Rarely          2                 3        869       Yes
# 37      Sales  Travel_Rarely          3                 2        890        No
# 46      Sales     Non-Travel          4                23       1065        No

# %%
rnd_lifeSciences=data[(data['Department']=='Research & Development') & (data['EducationField']=='Life Sciences') ]
rnd_lifeSciences.head()
# Out:
#    Age OverTime MaritalStatus                 JobRole  Gender EducationField  \
# 1   49       No       Married      Research Scientist    Male  Life Sciences
# 3   33      Yes       Married      Research Scientist  Female  Life Sciences
# 5   32       No        Single   Laboratory Technician    Male  Life Sciences
# 7   30       No      Divorced   Laboratory Technician    Male  Life Sciences
# 8   38       No        Single  Manufacturing Director    Male  Life Sciences
#
#                Department     BusinessTravel  Education  DistanceFromHome  \
# 1  Research & Development  Travel_Frequently          1                 8
# 3  Research & Development  Travel_Frequently          4                 3
# 5  Research & Development  Travel_Frequently          2                 2
# 7  Research & Development      Travel_Rarely          1                24
# 8  Research & Development  Travel_Frequently          3                23
#
#    DailyRate Attrition
# 1        279        No
# ...

# %%
hr_techDeg=data[(data['Department']=='Human Resources') & (data['EducationField']=='Technical Degree') ]
hr_techDeg.head()
# Out:
#       Age OverTime MaritalStatus          JobRole  Gender    EducationField  \
# 350    42      Yes      Divorced  Human Resources    Male  Technical Degree
# 422    19       No        Single  Human Resources    Male  Technical Degree
# 835    35       No        Single  Human Resources    Male  Technical Degree
# 1039   34       No       Married  Human Resources  Female  Technical Degree
#
#            Department BusinessTravel  Education  DistanceFromHome  DailyRate  \
# 350   Human Resources  Travel_Rarely          1                 2        544
# 422   Human Resources  Travel_Rarely          2                 2        489
# 835   Human Resources  Travel_Rarely          4                 8        528
# 1039  Human Resources  Travel_Rarely          4                 9       1107
#
#      Attrition
# 350         No
# 422        Yes
# 835         No
# 1039       Yes

# %%
data['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=data, x='JobRole')
plt.xticks(rotation=45, ha='right')  
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
data.head()
# Out:
#    Age OverTime MaritalStatus                JobRole  Gender EducationField  \
# 0   41      Yes        Single        Sales Executive  Female  Life Sciences
# 1   49       No       Married     Research Scientist    Male  Life Sciences
# 2   37      Yes        Single  Laboratory Technician    Male          Other
# 3   33      Yes       Married     Research Scientist  Female  Life Sciences
# 4   27       No       Married  Laboratory Technician    Male        Medical
#
#                Department     BusinessTravel  Education  DistanceFromHome  \
# 0                   Sales      Travel_Rarely          2                 1
# 1  Research & Development  Travel_Frequently          1                 8
# 2  Research & Development      Travel_Rarely          2                 2
# 3  Research & Development  Travel_Frequently          4                 3
# 4  Research & Development      Travel_Rarely          1                 2
#
#    DailyRate Attrition
# 0       1102       Yes
# ...

# %%
ax = sns.countplot(data=data, x='Gender', palette="mako", edgecolor='black')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_21640\2066302813.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=data, x='Gender', palette="mako", edgecolor='black')

# %%
data.groupby(['Gender'])['Department'].value_counts().sort_values(ascending=False)
# Out:
# Gender  Department
# Male    Research & Development    582
# Female  Research & Development    379
# Male    Sales                     257
# Female  Sales                     189
# Male    Human Resources            43
# Female  Human Resources            20
# Name: count, dtype: int64

# %%
data.groupby(['Gender'])['EducationField'].value_counts().sort_values(ascending=False)
# Out:
# Gender  EducationField
# Male    Life Sciences       366
#         Medical             274
# Female  Life Sciences       240
#         Medical             190
# Male    Marketing            90
#         Technical Degree     80
# Female  Marketing            69
# Male    Other                53
# Female  Technical Degree     52
#         Other                29
# Male    Human Resources      19
# Female  Human Resources       8
# Name: count, dtype: int64

# %%
data.groupby(['Gender'])['Attrition'].value_counts().sort_values(ascending=False)
# Out:
# Gender  Attrition
# Male    No           732
# Female  No           501
# Male    Yes          150
# Female  Yes           87
# Name: count, dtype: int64

# %%
grouped_data = data.groupby(['Gender', 'Attrition']).size().reset_index(name='Counts')

plt.figure(figsize=(12, 6))
attritionGender = sns.barplot(x='Gender', y='Counts', hue='Attrition', data=grouped_data, palette="autumn", edgecolor='black')

for container in attritionGender.containers:
    attritionGender.bar_label(container)

plt.xticks(rotation=0, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
data.groupby(['Gender'])['BusinessTravel'].value_counts().sort_values(ascending=False)
# Out:
# Gender  BusinessTravel
# Male    Travel_Rarely        621
# Female  Travel_Rarely        422
# Male    Travel_Frequently    160
# Female  Travel_Frequently    117
# Male    Non-Travel           101
# Female  Non-Travel            49
# Name: count, dtype: int64

# %%
grouped_data = data.groupby(['Gender', 'BusinessTravel']).size().reset_index(name='Counts')

plt.figure(figsize=(12, 6))
businessTravelGender = sns.barplot(x='Gender', y='Counts', hue='BusinessTravel', data=grouped_data, palette="viridis", edgecolor='black')

for container in businessTravelGender.containers:
    businessTravelGender.bar_label(container)

plt.xticks(rotation=0, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
grouped_data = data.groupby(['Gender', 'EducationField']).size().reset_index(name='Counts')

plt.figure(figsize=(14, 7))
educationFieldGender = sns.barplot(x='Gender', y='Counts', hue='EducationField', data=grouped_data, palette="husl", edgecolor='black')

for container in educationFieldGender.containers:
    educationFieldGender.bar_label(container)

plt.xticks(rotation=0, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
grouped_data = data.groupby(['Gender', 'BusinessTravel']).size().reset_index(name='Counts')

plt.figure(figsize=(12, 6))
attritionGender = sns.barplot(x='Gender', y='Counts', hue='BusinessTravel', data=grouped_data, palette="magma", edgecolor='black')

for container in attritionGender.containers:
    attritionGender.bar_label(container)

plt.xticks(rotation=0, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
grouped_data = data.groupby(['Gender', 'MaritalStatus']).size().reset_index(name='Counts')

plt.figure(figsize=(12, 6))
attritionGender = sns.barplot(x='Gender', y='Counts', hue='MaritalStatus', data=grouped_data, palette="viridis", edgecolor='black')

for container in attritionGender.containers:
    attritionGender.bar_label(container)

plt.xticks(rotation=0, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data, hue="Gender")

# %%
sns.pairplot(data, hue="MaritalStatus")

# %%
sns.pairplot(data, hue="BusinessTravel")

# %%
sns.pairplot(data, hue="Age")
